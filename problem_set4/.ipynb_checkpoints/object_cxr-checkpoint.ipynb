# %%
import pandas as pd
from PIL import Image, ImageDraw
import json
import matplotlib.pyplot as plt
import numpy as np
from pathlib import Path
from shapely.geometry import LineString
from shapely.algorithms.polylabel import polylabel
from shapely.ops import unary_union
import torchvision
from torchvision.models.detection.mask_rcnn import MaskRCNNPredictor
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor
import torchvision.transforms as transforms
import torch
import os
import utils
from engine import train_one_epoch
from sklearn.metrics import roc_auc_score, roc_curve, auc

# %% [markdown]
# Visualzing the original dataset

# %%
from google.colab import drive
drive.mount('/content/drive')

boxes = []
split = 'dev'

def _get_detection_model(num_classes):
    # load a model pre-trained pre-trained on COCO
    model = torchvision.models.detection.fasterrcnn_resnet50_fpn(pretrained=True)
    # get number of input features for the classifier
    in_features = model.roi_heads.box_predictor.cls_score.in_features
    # replace the pre-trained head with a new one
    model.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes)
    return model


OBJECT_SEP = ';'
ANNOTATION_SEP = ' '
# Each data is separated by <space>, each of bounding box is separated by ;
# First data is to defining shape of bbox, last 4 is the position
def draw_annotation(im, anno_str, fill=(255, 63, 63, 40)):
    draw = ImageDraw.Draw(im, mode="RGBA")
    for anno in anno_str.split(OBJECT_SEP):
        anno = list(map(int, anno.split(ANNOTATION_SEP)))
        if anno[0] == 0:
            draw.rectangle(anno[1:], fill=fill)
        elif anno[0] == 1:
            draw.ellipse(anno[1:], fill=fill)
        else:
            draw.polygon(anno[1:], fill=fill)
            draw.polygon(anno[1:],fill = fill)
data_dir = 'drive/MyDrive/object-cxr/'
label_train = pd.read_csv(data_dir+'train.csv', na_filter = False)
label_dev = pd.read_csv(data_dir+'dev.csv', na_filter = False)

label_train = label_train.loc[label_train['annotation'].astype(bool)].reset_index(drop=True)
img_class_dict_tr = dict(zip(label_train.image_name, label_train.annotation))
img_class_dict_dev = dict(zip(label_dev.image_name, label_dev.annotation))
fig, axs = plt.subplots(nrows=1, ncols=4, subplot_kw=dict(xticks=[], yticks=[]),
                        figsize=(24, 6))

example_idxes = [127,567,34,123]
for row, ax in zip(label_train.iloc[example_idxes].itertuples(index=False), axs):
    im = Image.open(data_dir + "train/" + row.image_name).convert("RGB")
    if row.annotation:
        draw_annotation(im, row.annotation)
    
    ax.imshow(im)
    ax.set_title(f"{row.image_name}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# This class is used for defining dataset for foreign object

# %%
class ForeignObjectDataset(object):
    
    def __init__(self, datafolder, datatype='train', transform = True, labels_dict={}):
        self.datafolder = datafolder
        self.datatype = datatype
        self.labels_dict = labels_dict
        # load all image files, sorting them to
        # ensure that they are aligned
        self.image_files_list = [s for s in sorted(os.listdir(datafolder)) if s in labels_dict.keys()]
        self.transform = transform
        self.annotations = [labels_dict[i] for i in self.image_files_list]
            
    def __getitem__(self, idx):
        # load images 
        img_name = self.image_files_list[idx]
        img_path = os.path.join(self.datafolder, img_name)
        # note that we haven't converted the mask to RGB,
        # because each color corresponds to a different instance
        # with 0 being background
        img = Image.open(img_path).convert("RGB")
        width, height = img.size[0],img.size[1]  
        
        if self.datatype == 'train':
            annotation = self.labels_dict[img_name]
            
            boxes = []
        
            # take the information about the bounding box and append it to list of boxes
            if type(annotation) == str:
                annotation_list = annotation.split(';')
                for anno in annotation_list:
                    x = []
                    y = []
                
                    anno = anno[2:]
                    anno = anno.split(' ')
                    for i in range(len(anno)):
                        if i % 2 == 0:
                            x.append(float(anno[i]))
                        else:
                            y.append(float(anno[i]))
                        
                    xmin = min(x)/width * 600
                    xmax = max(x)/width * 600
                    ymin = min(y)/height * 600
                    ymax = max(y)/height * 600
                    boxes.append([xmin, ymin, xmax, ymax])

            # convert everything into a torch.Tensor
            boxes = torch.as_tensor(boxes, dtype=torch.float32)
            # there is only one class
            labels = torch.ones((len(boxes),), dtype=torch.int64)

            image_id = torch.tensor([idx])
            area = (boxes[:, 3] - boxes[:, 1]) * (boxes[:, 2] - boxes[:, 0])
            # suppose all instances are not crowd
            iscrowd = torch.zeros((len(boxes),), dtype=torch.int64)

            target = {}
            target["boxes"] = boxes
            target["labels"] = labels
            target["image_id"] = image_id
            target["area"] = area
            target["iscrowd"] = iscrowd
            
            if self.transform is not None:
                img = self.transform(img)
                
            return img, target
        
        if self.datatype == 'dev':
            
            if self.labels_dict[img_name] == '':
                label = 0
            else:
                label = 1
            
            if self.transform is not None:
                img = self.transform(img)

            return img, label, width, height

        

    def __len__(self):
        return len(self.image_files_list)

# %% [markdown]
# Perform the training and validating

# %%
def main():
    # train on the GPU or on the CPU, if a GPU is not available
    device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

    data_transforms = transforms.Compose([
    transforms.Resize((600,600)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])

    dataset_train = ForeignObjectDataset(datafolder= data_dir + 'train/',
                                         datatype='train', transform=data_transforms,
                                         labels_dict=img_class_dict_tr)
    dataset_dev = ForeignObjectDataset(datafolder= data_dir + 'dev/', datatype='dev',
                                       transform=data_transforms,
                                       labels_dict=img_class_dict_dev)



    

    num_classes = 2# 1 class odd object + background (human body)
    # set up the data and the option for the training
    data_loader = torch.utils.data.DataLoader(
                  dataset_train, batch_size=8, shuffle= True, num_workers=4,
                  collate_fn=utils.collate_fn)
    
    data_loader_val = torch.utils.data.DataLoader(
        dataset_dev, batch_size=1, shuffle= False, num_workers=4,
        collate_fn=utils.collate_fn)
    
    # get the model using our helper function
    model_ft = _get_detection_model(num_classes)
    # move model to the right device
    model_ft.to(device)
    
    # construct an optimizer
    params = [p for p in model_ft.parameters() if p.requires_grad]
    optimizer = torch.optim.SGD(params, lr=0.005,
                                momentum=0.9, weight_decay=0.0005)
    # and a learning rate scheduler
    # and a learning rate scheduler which decreases the learning rate by
    # 10x every 5 epochs
    lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer,
                                                   step_size=5,
                                                   gamma=0.1)

    num_epochs = 7

    auc_max = 0

    for epoch in range(num_epochs):
        # train for one epoch, printing every 20 iterations
        train_one_epoch(model_ft, optimizer, data_loader, device, epoch, print_freq=20)
        
        # update the learning rate
        lr_scheduler.step()
        
        model_ft.eval()
        val_pred = []
        val_label = []
        
        # Evaluating each epoch
        for batch_i, (image, label,  width, height) in enumerate(data_loader_val):
            image = list(img.to(device) for img in image)
            
            val_label.append(label[-1])

            outputs = model_ft(image)
            if len(outputs[-1]['boxes']) == 0:
                val_pred.append(0)
            else:
                val_pred.append(torch.max(outputs[-1]['scores']).tolist())
        
        val_pred_label = []
        for i in range(len(val_pred)):
            if val_pred[i] >= 0.5:
                val_pred_label.append(1)
            else:
                val_pred_label.append(0)
                
        number = 0
        
        for i in range(len(val_pred_label)):
            if val_pred_label[i] == val_label[i]:
                number += 1
        acc = number / len(val_pred_label)
        
        auc = roc_auc_score(val_label,val_pred)
        print('Epoch: ', epoch, '| val acc: %.4f' % acc, '| val auc: %.4f' % auc)
        
        if auc > auc_max:
            auc_max = auc
            print('Best Epoch: ', epoch, '| val acc: %.4f' % acc, '| Best val auc: %.4f' % auc_max)
            torch.save(model_ft.state_dict(), "drive/MyDrive/object-cxr/model.pt")

# %%
main()
# Out:
# Epoch: [0]  [  0/500]  eta: 0:35:35  lr: 0.000015  loss: 1.4966 (1.4966)  loss_classifier: 0.8854 (0.8854)  loss_box_reg: 0.0261 (0.0261)  loss_objectness: 0.5570 (0.5570)  loss_rpn_box_reg: 0.0282 (0.0282)  time: 4.2700
# Epoch: [0]  [ 20/500]  eta: 0:13:43  lr: 0.000215  loss: 0.4472 (0.6202)  loss_classifier: 0.1617 (0.2724)  loss_box_reg: 0.0587 (0.0637)  loss_objectness: 0.2010 (0.2652)  loss_rpn_box_reg: 0.0184 (0.0190)  time: 1.5885
# Epoch: [0]  [ 40/500]  eta: 0:12:45  lr: 0.000415  loss: 0.3430 (0.4911)  loss_classifier: 0.1218 (0.2037)  loss_box_reg: 0.0767 (0.0712)  loss_objectness: 0.1215 (0.1996)  loss_rpn_box_reg: 0.0122 (0.0166)  time: 1.6104
# Epoch: [0]  [ 60/500]  eta: 0:12:12  lr: 0.000616  loss: 0.3089 (0.4394)  loss_classifier: 0.1141 (0.1752)  loss_box_reg: 0.0810 (0.0765)  loss_objectness: 0.0992 (0.1722)  loss_rpn_box_reg: 0.0109 (0.0155)  time: 1.6642
# Epoch: [0]  [ 80/500]  eta: 0:11:43  lr: 0.000816  loss: 0.3360 (0.4163)  loss_classifier: 0.1273 (0.1643)  loss_box_reg: 0.1032 (0.0851)  loss_objectness: 0.0857 (0.1518)  loss_rpn_box_reg: 0.0128 (0.0151)  time: 1.7073
# Epoch: [0]  [100/500]  eta: 0:11:09  lr: 0.001016  loss: 0.3114 (0.3981)  loss_classifier: 0.1207 (0.1575)  loss_box_reg: 0.1064 (0.0902)  loss_objectness: 0.0699 (0.1357)  loss_rpn_box_reg: 0.0117 (0.0146)  time: 1.6689
# Epoch: [0]  [120/500]  eta: 0:10:37  lr: 0.001216  loss: 0.3996 (0.3968)  loss_classifier: 0.1601 (0.1577)  loss_box_reg: 0.1487 (0.1004)  loss_objectness: 0.0667 (0.1245)  loss_rpn_box_reg: 0.0114 (0.0142)  time: 1.6923
# Epoch: [0]  [140/500]  eta: 0:10:04  lr: 0.001416  loss: 0.3367 (0.3954)  loss_classifier: 0.1450 (0.1572)  loss_box_reg: 0.1409 (0.1084)  loss_objectness: 0.0503 (0.1151)  loss_rpn_box_reg: 0.0097 (0.0146)  time: 1.6966
# Epoch: [0]  [160/500]  eta: 0:09:31  lr: 0.001617  loss: 0.3958 (0.3967)  loss_classifier: 0.1515 (0.1570)  loss_box_reg: 0.1510 (0.1152)  loss_objectness: 0.0649 (0.1098)  loss_rpn_box_reg: 0.0126 (0.0148)  time: 1.6788
# Epoch: [0]  [180/500]  eta: 0:08:57  lr: 0.001817  loss: 0.3524 (0.3913)  loss_classifier: 0.1441 (0.1550)  loss_box_reg: 0.1461 (0.1185)  loss_objectness: 0.0518 (0.1036)  loss_rpn_box_reg: 0.0097 (0.0143)  time: 1.6890
# Epoch: [0]  [200/500]  eta: 0:08:24  lr: 0.002017  loss: 0.3429 (0.3861)  loss_classifier: 0.1339 (0.1533)  loss_box_reg: 0.1469 (0.1213)  loss_objectness: 0.0398 (0.0977)  loss_rpn_box_reg: 0.0079 (0.0137)  time: 1.6947
# Epoch: [0]  [220/500]  eta: 0:07:50  lr: 0.002217  loss: 0.3682 (0.3860)  loss_classifier: 0.1427 (0.1528)  loss_box_reg: 0.1535 (0.1255)  loss_objectness: 0.0455 (0.0940)  loss_rpn_box_reg: 0.0108 (0.0136)  time: 1.6784
# Epoch: [0]  [240/500]  eta: 0:07:17  lr: 0.002417  loss: 0.3400 (0.3846)  loss_classifier: 0.1414 (0.1522)  loss_box_reg: 0.1522 (0.1285)  loss_objectness: 0.0433 (0.0906)  loss_rpn_box_reg: 0.0079 (0.0133)  time: 1.7102
# Epoch: [0]  [260/500]  eta: 0:06:44  lr: 0.002618  loss: 0.3363 (0.3829)  loss_classifier: 0.1406 (0.1518)  loss_box_reg: 0.1575 (0.1306)  loss_objectness: 0.0382 (0.0873)  loss_rpn_box_reg: 0.0108 (0.0132)  time: 1.7173
# Epoch: [0]  [280/500]  eta: 0:06:11  lr: 0.002818  loss: 0.3656 (0.3836)  loss_classifier: 0.1498 (0.1515)  loss_box_reg: 0.1619 (0.1330)  loss_objectness: 0.0406 (0.0856)  loss_rpn_box_reg: 0.0083 (0.0134)  time: 1.6997
# Epoch: [0]  [300/500]  eta: 0:05:37  lr: 0.003018  loss: 0.3200 (0.3811)  loss_classifier: 0.1274 (0.1503)  loss_box_reg: 0.1486 (0.1348)  loss_objectness: 0.0399 (0.0828)  loss_rpn_box_reg: 0.0075 (0.0131)  time: 1.7135
# Epoch: [0]  [320/500]  eta: 0:05:04  lr: 0.003218  loss: 0.3315 (0.3794)  loss_classifier: 0.1312 (0.1494)  loss_box_reg: 0.1482 (0.1363)  loss_objectness: 0.0389 (0.0806)  loss_rpn_box_reg: 0.0077 (0.0131)  time: 1.7151
# Epoch: [0]  [340/500]  eta: 0:04:30  lr: 0.003418  loss: 0.3263 (0.3768)  loss_classifier: 0.1205 (0.1482)  loss_box_reg: 0.1524 (0.1373)  loss_objectness: 0.0355 (0.0783)  loss_rpn_box_reg: 0.0094 (0.0130)  time: 1.7136
# Epoch: [0]  [360/500]  eta: 0:03:56  lr: 0.003619  loss: 0.3156 (0.3749)  loss_classifier: 0.1283 (0.1473)  loss_box_reg: 0.1393 (0.1379)  loss_objectness: 0.0328 (0.0770)  loss_rpn_box_reg: 0.0084 (0.0128)  time: 1.6946
# Epoch: [0]  [380/500]  eta: 0:03:23  lr: 0.003819  loss: 0.3220 (0.3732)  loss_classifier: 0.1237 (0.1460)  loss_box_reg: 0.1325 (0.1380)  loss_objectness: 0.0429 (0.0765)  loss_rpn_box_reg: 0.0097 (0.0127)  time: 1.7047
# Epoch: [0]  [400/500]  eta: 0:02:49  lr: 0.004019  loss: 0.3520 (0.3722)  loss_classifier: 0.1370 (0.1457)  loss_box_reg: 0.1626 (0.1397)  loss_objectness: 0.0319 (0.0743)  loss_rpn_box_reg: 0.0077 (0.0125)  time: 1.7213
# Epoch: [0]  [420/500]  eta: 0:02:15  lr: 0.004219  loss: 0.3289 (0.3708)  loss_classifier: 0.1332 (0.1452)  loss_box_reg: 0.1544 (0.1407)  loss_objectness: 0.0309 (0.0725)  loss_rpn_box_reg: 0.0090 (0.0123)  time: 1.7122
# Epoch: [0]  [440/500]  eta: 0:01:41  lr: 0.004419  loss: 0.3318 (0.3691)  loss_classifier: 0.1310 (0.1445)  loss_box_reg: 0.1661 (0.1420)  loss_objectness: 0.0245 (0.0705)  loss_rpn_box_reg: 0.0079 (0.0122)  time: 1.6950
# Epoch: [0]  [460/500]  eta: 0:01:07  lr: 0.004620  loss: 0.3004 (0.3672)  loss_classifier: 0.1172 (0.1435)  loss_box_reg: 0.1395 (0.1423)  loss_objectness: 0.0305 (0.0693)  loss_rpn_box_reg: 0.0078 (0.0120)  time: 1.7971
# Epoch: [0]  [480/500]  eta: 0:00:33  lr: 0.004820  loss: 0.3385 (0.3659)  loss_classifier: 0.1303 (0.1430)  loss_box_reg: 0.1660 (0.1432)  loss_objectness: 0.0325 (0.0678)  loss_rpn_box_reg: 0.0081 (0.0119)  time: 1.6960
# Epoch: [0]  [499/500]  eta: 0:00:01  lr: 0.005000  loss: 0.3170 (0.3643)  loss_classifier: 0.1182 (0.1423)  loss_box_reg: 0.1597 (0.1438)  loss_objectness: 0.0324 (0.0665)  loss_rpn_box_reg: 0.0078 (0.0118)  time: 1.6678
# Epoch: [0] Total time: 0:14:09 (1.6986 s / it)
# Epoch:  0 | val acc: 0.7210 | val auc: 0.8528
# Best Epoch:  0 | val acc: 0.7210 | Best val auc: 0.8528
# Epoch: [1]  [  0/500]  eta: 0:53:44  lr: 0.005000  loss: 0.2670 (0.2670)  loss_classifier: 0.1105 (0.1105)  loss_box_reg: 0.1169 (0.1169)  loss_objectness: 0.0270 (0.0270)  loss_rpn_box_reg: 0.0126 (0.0126)  time: 6.4489
# Epoch: [1]  [ 20/500]  eta: 0:15:26  lr: 0.005000  loss: 0.3089 (0.3107)  loss_classifier: 0.1202 (0.1164)  loss_box_reg: 0.1478 (0.1511)  loss_objectness: 0.0288 (0.0336)  loss_rpn_box_reg: 0.0079 (0.0096)  time: 1.7041
# Epoch: [1]  [ 40/500]  eta: 0:13:48  lr: 0.005000  loss: 0.2999 (0.3061)  loss_classifier: 0.1154 (0.1156)  loss_box_reg: 0.1627 (0.1531)  loss_objectness: 0.0207 (0.0292)  loss_rpn_box_reg: 0.0069 (0.0082)  time: 1.6640
# Epoch: [1]  [ 60/500]  eta: 0:12:54  lr: 0.005000  loss: 0.3082 (0.3121)  loss_classifier: 0.1107 (0.1182)  loss_box_reg: 0.1416 (0.1523)  loss_objectness: 0.0330 (0.0317)  loss_rpn_box_reg: 0.0082 (0.0099)  time: 1.6749
# Epoch: [1]  [ 80/500]  eta: 0:12:13  lr: 0.005000  loss: 0.3177 (0.3140)  loss_classifier: 0.1270 (0.1198)  loss_box_reg: 0.1456 (0.1538)  loss_objectness: 0.0239 (0.0310)  loss_rpn_box_reg: 0.0075 (0.0094)  time: 1.7078
# Epoch: [2]  [  0/500]  eta: 0:41:39  lr: 0.005000  loss: 0.3863 (0.3863)  loss_classifier: 0.1385 (0.1385)  loss_box_reg: 0.2288 (0.2288)  loss_objectness: 0.0107 (0.0107)  loss_rpn_box_reg: 0.0083 (0.0083)  time: 5.0000
# Epoch: [2]  [ 20/500]  eta: 0:15:06  lr: 0.005000  loss: 0.3351 (0.3235)  loss_classifier: 0.1097 (0.1177)  loss_box_reg: 0.1803 (0.1751)  loss_objectness: 0.0179 (0.0232)  loss_rpn_box_reg: 0.0063 (0.0076)  time: 1.7338
# Epoch: [2]  [ 40/500]  eta: 0:13:41  lr: 0.005000  loss: 0.2706 (0.3111)  loss_classifier: 0.1090 (0.1148)  loss_box_reg: 0.1538 (0.1667)  loss_objectness: 0.0185 (0.0222)  loss_rpn_box_reg: 0.0058 (0.0073)  time: 1.6767
# Epoch: [2]  [ 60/500]  eta: 0:12:50  lr: 0.005000  loss: 0.2822 (0.3048)  loss_classifier: 0.1061 (0.1129)  loss_box_reg: 0.1491 (0.1620)  loss_objectness: 0.0155 (0.0226)  loss_rpn_box_reg: 0.0061 (0.0074)  time: 1.6817
# Epoch: [2]  [ 80/500]  eta: 0:12:08  lr: 0.005000  loss: 0.3299 (0.3099)  loss_classifier: 0.1176 (0.1155)  loss_box_reg: 0.1766 (0.1653)  loss_objectness: 0.0204 (0.0219)  loss_rpn_box_reg: 0.0063 (0.0073)  time: 1.6865
# Epoch: [2]  [100/500]  eta: 0:11:29  lr: 0.005000  loss: 0.3074 (0.3111)  loss_classifier: 0.1134 (0.1167)  loss_box_reg: 0.1613 (0.1646)  loss_objectness: 0.0221 (0.0221)  loss_rpn_box_reg: 0.0078 (0.0076)  time: 1.6737
# Epoch: [2]  [120/500]  eta: 0:10:52  lr: 0.005000  loss: 0.3681 (0.3157)  loss_classifier: 0.1343 (0.1186)  loss_box_reg: 0.1892 (0.1677)  loss_objectness: 0.0170 (0.0219)  loss_rpn_box_reg: 0.0072 (0.0075)  time: 1.6830
# Epoch: [2]  [140/500]  eta: 0:10:17  lr: 0.005000  loss: 0.3008 (0.3161)  loss_classifier: 0.1188 (0.1193)  loss_box_reg: 0.1530 (0.1673)  loss_objectness: 0.0184 (0.0220)  loss_rpn_box_reg: 0.0065 (0.0074)  time: 1.7008
# Epoch: [2]  [160/500]  eta: 0:09:41  lr: 0.005000  loss: 0.3096 (0.3172)  loss_classifier: 0.1169 (0.1197)  loss_box_reg: 0.1547 (0.1670)  loss_objectness: 0.0175 (0.0225)  loss_rpn_box_reg: 0.0066 (0.0080)  time: 1.6840
# Epoch: [2]  [180/500]  eta: 0:09:06  lr: 0.005000  loss: 0.2661 (0.3128)  loss_classifier: 0.0975 (0.1182)  loss_box_reg: 0.1383 (0.1642)  loss_objectness: 0.0190 (0.0225)  loss_rpn_box_reg: 0.0056 (0.0079)  time: 1.6794
# Epoch: [2]  [420/500]  eta: 0:02:16  lr: 0.005000  loss: 0.2842 (0.3063)  loss_classifier: 0.1141 (0.1153)  loss_box_reg: 0.1442 (0.1606)  loss_objectness: 0.0136 (0.0224)  loss_rpn_box_reg: 0.0059 (0.0080)  time: 1.7148
# Epoch: [2]  [440/500]  eta: 0:01:42  lr: 0.005000  loss: 0.2924 (0.3058)  loss_classifier: 0.1042 (0.1150)  loss_box_reg: 0.1588 (0.1606)  loss_objectness: 0.0153 (0.0223)  loss_rpn_box_reg: 0.0056 (0.0080)  time: 1.7202
# Epoch: [2]  [460/500]  eta: 0:01:08  lr: 0.005000  loss: 0.3207 (0.3065)  loss_classifier: 0.1180 (0.1152)  loss_box_reg: 0.1559 (0.1609)  loss_objectness: 0.0232 (0.0224)  loss_rpn_box_reg: 0.0074 (0.0080)  time: 1.7097
# Epoch: [2]  [480/500]  eta: 0:00:34  lr: 0.005000  loss: 0.3481 (0.3076)  loss_classifier: 0.1182 (0.1154)  loss_box_reg: 0.1788 (0.1616)  loss_objectness: 0.0227 (0.0226)  loss_rpn_box_reg: 0.0073 (0.0080)  time: 1.6894
# Epoch: [2]  [499/500]  eta: 0:00:01  lr: 0.005000  loss: 0.2811 (0.3074)  loss_classifier: 0.1036 (0.1153)  loss_box_reg: 0.1491 (0.1615)  loss_objectness: 0.0183 (0.0226)  loss_rpn_box_reg: 0.0064 (0.0080)  time: 1.6771
# Epoch: [2] Total time: 0:14:12 (1.7054 s / it)
# Epoch:  2 | val acc: 0.7770 | val auc: 0.9149
# Best Epoch:  2 | val acc: 0.7770 | Best val auc: 0.9149
# Epoch: [3]  [  0/500]  eta: 0:44:15  lr: 0.005000  loss: 0.3122 (0.3122)  loss_classifier: 0.1060 (0.1060)  loss_box_reg: 0.1935 (0.1935)  loss_objectness: 0.0074 (0.0074)  loss_rpn_box_reg: 0.0053 (0.0053)  time: 5.3116
# Epoch: [3]  [ 20/500]  eta: 0:15:11  lr: 0.005000  loss: 0.3091 (0.2995)  loss_classifier: 0.1145 (0.1108)  loss_box_reg: 0.1664 (0.1697)  loss_objectness: 0.0132 (0.0125)  loss_rpn_box_reg: 0.0058 (0.0065)  time: 1.7273
# Epoch: [3]  [ 40/500]  eta: 0:17:24  lr: 0.005000  loss: 0.3426 (0.3209)  loss_classifier: 0.1220 (0.1181)  loss_box_reg: 0.1857 (0.1811)  loss_objectness: 0.0135 (0.0147)  loss_rpn_box_reg: 0.0055 (0.0069)  time: 2.6614
# Epoch: [3]  [ 60/500]  eta: 0:15:19  lr: 0.005000  loss: 0.2956 (0.3216)  loss_classifier: 0.1045 (0.1179)  loss_box_reg: 0.1681 (0.1769)  loss_objectness: 0.0189 (0.0190)  loss_rpn_box_reg: 0.0067 (0.0079)  time: 1.7205
# Epoch: [3]  [ 80/500]  eta: 0:14:02  lr: 0.005000  loss: 0.2533 (0.3106)  loss_classifier: 0.0964 (0.1149)  loss_box_reg: 0.1329 (0.1699)  loss_objectness: 0.0131 (0.0182)  loss_rpn_box_reg: 0.0056 (0.0076)  time: 1.7522
  loss_rpn_box_reg: 0.0041 (0.0041)  time: 5.5609
# Epoch: [4]  [ 20/500]  eta: 0:21:34  lr: 0.005000  loss: 0.2601 (0.2696)  loss_classifier: 0.0962 (0.1017)  loss_box_reg: 0.1495 (0.1474)  loss_objectness: 0.0126 (0.0141)  loss_rpn_box_reg: 0.0060 (0.0064)  time: 2.5543
# Epoch: [4]  [ 40/500]  eta: 0:16:56  lr: 0.005000  loss: 0.2468 (0.2714)  loss_classifier: 0.0903 (0.0988)  loss_box_reg: 0.1400 (0.1501)  loss_objectness: 0.0116 (0.0155)  loss_rpn_box_reg: 0.0054 (0.0070)  time: 1.6993
# Epoch: [4]  [ 60/500]  eta: 0:14:56  lr: 0.005000  loss: 0.2331 (0.2675)  loss_classifier: 0.0893 (0.0980)  loss_box_reg: 0.1332 (0.1488)  loss_objectness: 0.0104 (0.0142)  loss_rpn_box_reg: 0.0051 (0.0065)  time: 1.6825
# Epoch: [4]  [ 80/500]  eta: 0:13:41  lr: 0.005000  loss: 0.2891 (0.2752)  loss_classifier: 0.1096 (0.1008)  loss_box_reg: 0.1582 (0.1539)  loss_objectness: 0.0128 (0.0142)  loss_rpn_box_reg: 0.0052 (0.0063)  time: 1.7064
# Epoch: [4]  [100/500]  eta: 0:12:41  lr: 0.005000  loss: 0.3124 (0.2821)  loss_classifier: 0.1024 (0.1025)  loss_box_reg: 0.1651 (0.1572)  loss_objectness: 0.0119 (0.0154)  loss_rpn_box_reg: 0.0064 (0.0070)  time: 1.6940
# Epoch: [4]  [120/500]  eta: 0:11:50  lr: 0.005000  loss: 0.2877 (0.2826)  loss_classifier: 0.1061 (0.1030)  loss_box_reg: 0.1621 (0.1578)  loss_objectness: 0.0119 (0.0151)  loss_rpn_box_reg: 0.0048 (0.0068)  time: 1.7046
# Epoch: [4]  [140/500]  eta: 0:11:07  lr: 0.005000  loss: 0.2792 (0.2816)  loss_classifier: 0.1077 (0.1037)  loss_box_reg: 0.1392 (0.1554)  loss_objectness: 0.0204 (0.0159)  loss_rpn_box_reg: 0.0061 (0.0067)  time: 1.7545
# Epoch: [4]  [160/500]  eta: 0:10:23  lr: 0.005000  loss: 0.2746 (0.2794)  loss_classifier: 0.1008 (0.1030)  loss_box_reg: 0.1460 (0.1539)  loss_objectness: 0.0129 (0.0157)  loss_rpn_box_reg: 0.0056 (0.0068)  time: 1.6972
# Epoch: [4]  [180/500]  eta: 0:09:42  lr: 0.005000  loss: 0.2742 (0.2785)  loss_classifier: 0.0950 (0.1023)  loss_box_reg: 0.1366 (0.1536)  loss_objectness: 0.0141 (0.0156)  loss_rpn_box_reg: 0.0066 (0.0070)  time: 1.6986
# Epoch: [4]  [200/500]  eta: 0:09:02  lr: 0.005000  loss: 0.2656 (0.2777)  loss_classifier: 0.0909 (0.1019)  loss_box_reg: 0.1541 (0.1533)  loss_objectness: 0.0126 (0.0156)  loss_rpn_box_reg: 0.0059 (0.0069)  time: 1.6981
# Epoch: [4]  [420/500]  eta: 0:02:20  lr: 0.005000  loss: 0.2570 (0.2802)  loss_classifier: 0.1007 (0.1039)  loss_box_reg: 0.1423 (0.1538)  loss_objectness: 0.0139 (0.0157)  loss_rpn_box_reg: 0.0062 (0.0069)  time: 1.7229
# Epoch: [4]  [440/500]  eta: 0:01:45  lr: 0.005000  loss: 0.3179 (0.2817)  loss_classifier: 0.1059 (0.1043)  loss_box_reg: 0.1670 (0.1547)  loss_objectness: 0.0172 (0.0158)  loss_rpn_box_reg: 0.0062 (0.0069)  time: 1.7118
# Epoch: [4]  [460/500]  eta: 0:01:10  lr: 0.005000  loss: 0.3145 (0.2832)  loss_classifier: 0.1109 (0.1048)  loss_box_reg: 0.1870 (0.1557)  loss_objectness: 0.0120 (0.0158)  loss_rpn_box_reg: 0.0055 (0.0069)  time: 1.7106
# Epoch: [4]  [480/500]  eta: 0:00:35  lr: 0.005000  loss: 0.2950 (0.2841)  loss_classifier: 0.1044 (0.1050)  loss_box_reg: 0.1637 (0.1564)  loss_objectness: 0.0130 (0.0157)  loss_rpn_box_reg: 0.0055 (0.0069)  time: 1.7080
# Epoch: [4]  [499/500]  eta: 0:00:01  lr: 0.005000  loss: 0.2633 (0.2839)  loss_classifier: 0.1010 (0.1050)  loss_box_reg: 0.1486 (0.1561)  loss_objectness: 0.0130 (0.0158)  loss_rpn_box_reg: 0.0056 (0.0070)  time: 1.6895
# Epoch: [4] Total time: 0:14:36 (1.7534 s / it)
# Epoch:  4 | val acc: 0.7830 | val auc: 0.9160
# Epoch: [5]  [  0/500]  eta: 0:58:19  lr: 0.000500  loss: 0.3345 (0.3345)  loss_classifier: 0.1239 (0.1239)  loss_box_reg: 0.1954 (0.1954)  loss_objectness: 0.0083 (0.0083)  loss_rpn_box_reg: 0.0070 (0.0070)  time: 6.9987
# Epoch: [5]  [ 20/500]  eta: 0:15:51  lr: 0.000500  loss: 0.2976 (0.2891)  loss_classifier: 0.0975 (0.1041)  loss_box_reg: 0.1696 (0.1646)  loss_objectness: 0.0145 (0.0143)  loss_rpn_box_reg: 0.0052 (0.0062)  time: 1.7308
# Epoch: [5]  [ 40/500]  eta: 0:14:00  lr: 0.000500  loss: 0.2717 (0.2815)  loss_classifier: 0.0956 (0.1018)  loss_box_reg: 0.1394 (0.1604)  loss_objectness: 0.0112 (0.0131)  loss_rpn_box_reg: 0.0062 (0.0063)  time: 1.6666
# Epoch: [5]  [ 60/500]  eta: 0:13:06  lr: 0.000500  loss: 0.2242 (0.2678)  loss_classifier: 0.0850 (0.0974)  loss_box_reg: 0.1311 (0.1514)  loss_objectness: 0.0109 (0.0131)  loss_rpn_box_reg: 0.0046 (0.0060)  time: 1.7028
# Epoch: [5]  [ 80/500]  eta: 0:12:20  lr: 0.000500  loss: 0.2553 (0.2637)  loss_classifier: 0.0890 (0.0957)  loss_box_reg: 0.1395 (0.1496)  loss_objectness: 0.0096 (0.0126)  loss_rpn_box_reg: 0.0047 (0.0058)  time: 1.6860
# Epoch: [5]  [100/500]  eta: 0:11:39  lr: 0.000500  loss: 0.2679 (0.2692)  loss_classifier: 0.0954 (0.0973)  loss_box_reg: 0.1591 (0.1525)  loss_objectness: 0.0096 (0.0129)  loss_rpn_box_reg: 0.0052 (0.0065)  time: 1.6912
# Epoch: [5]  [120/500]  eta: 0:11:01  lr: 0.000500  loss: 0.2294 (0.2625)  loss_classifier: 0.0810 (0.0948)  loss_box_reg: 0.1333 (0.1492)  loss_objectness: 0.0080 (0.0123)  loss_rpn_box_reg: 0.0043 (0.0063)  time: 1.7099
# Epoch: [5]  [140/500]  eta: 0:10:25  lr: 0.000500  loss: 0.2540 (0.2622)  loss_classifier: 0.0961 (0.0949)  loss_box_reg: 0.1394 (0.1490)  loss_objectness: 0.0079 (0.0120)  loss_rpn_box_reg: 0.0058 (0.0063)  time: 1.7160
# Epoch: [5]  [160/500]  eta: 0:09:49  lr: 0.000500  loss: 0.2474 (0.2599)  loss_classifier: 0.0862 (0.0943)  loss_box_reg: 0.1413 (0.1476)  loss_objectness: 0.0077 (0.0119)  loss_rpn_box_reg: 0.0045 (0.0062)  time: 1.7078
# Epoch: [5]  [180/500]  eta: 0:09:13  lr: 0.000500  loss: 0.2101 (0.2561)  loss_classifier: 0.0831 (0.0931)  loss_box_reg: 0.1115 (0.1450)  loss_objectness: 0.0100 (0.0119)  loss_rpn_box_reg: 0.0046 (0.0061)  time: 1.7055
# Epoch: [5]  [200/500]  eta: 0:08:38  lr: 0.000500  loss: 0.2524 (0.2574)  loss_classifier: 0.0923 (0.0933)  loss_box_reg: 0.1452 (0.1461)  loss_objectness: 0.0098 (0.0119)  loss_rpn_box_reg: 0.0059 (0.0061)  time: 1.7021
# Epoch: [5]  [220/500]  eta: 0:08:02  lr: 0.000500  loss: 0.2397 (0.2582)  loss_classifier: 0.0855 (0.0934)  loss_box_reg: 0.1474 (0.1472)  loss_objectness: 0.0078 (0.0116)  loss_rpn_box_reg: 0.0048 (0.0061)  time: 1.6915
# Epoch: [5]  [240/500]  eta: 0:07:28  lr: 0.000500  loss: 0.2246 (0.2562)  loss_classifier: 0.0768 (0.0926)  loss_box_reg: 0.1278 (0.1461)  loss_objectness: 0.0089 (0.0114)  loss_rpn_box_reg: 0.0046 (0.0060)  time: 1.7202
# Epoch: [5]  [260/500]  eta: 0:06:54  lr: 0.000500  loss: 0.2219 (0.2550)  loss_classifier: 0.0842 (0.0920)  loss_box_reg: 0.1330 (0.1459)  loss_objectness: 0.0066 (0.0112)  loss_rpn_box_reg: 0.0046 (0.0060)  time: 1.7405
# Epoch: [5]  [280/500]  eta: 0:06:19  lr: 0.000500  loss: 0.2581 (0.2555)  loss_classifier: 0.0947 (0.0921)  loss_box_reg: 0.1540 (0.1462)  loss_objectness: 0.0087 (0.0112)  loss_rpn_box_reg: 0.0051 (0.0060)  time: 1.7231
# Epoch: [5]  [300/500]  eta: 0:05:44  lr: 0.000500  loss: 0.2310 (0.2555)  loss_classifier: 0.0833 (0.0920)  loss_box_reg: 0.1377 (0.1464)  loss_objectness: 0.0086 (0.0111)  loss_rpn_box_reg: 0.0046 (0.0059)  time: 1.7070
# Epoch: [5]  [320/500]  eta: 0:05:10  lr: 0.000500  loss: 0.2469 (0.2561)  loss_classifier: 0.0940 (0.0924)  loss_box_reg: 0.1481 (0.1464)  loss_objectness: 0.0119 (0.0113)  loss_rpn_box_reg: 0.0052 (0.0060)  time: 1.7365
# Epoch: [5]  [340/500]  eta: 0:04:35  lr: 0.000500  loss: 0.2465 (0.2563)  loss_classifier: 0.0833 (0.0923)  loss_box_reg: 0.1449 (0.1469)  loss_objectness: 0.0092 (0.0112)  loss_rpn_box_reg: 0.0054 (0.0059)  time: 1.7236
# Epoch: [5]  [360/500]  eta: 0:04:03  lr: 0.000500  loss: 0.2434 (0.2559)  loss_classifier: 0.0902 (0.0920)  loss_box_reg: 0.1383 (0.1465)  loss_objectness: 0.0103 (0.0113)  loss_rpn_box_reg: 0.0049 (0.0061)  time: 1.9413
# Epoch: [5]  [380/500]  eta: 0:03:28  lr: 0.000500  loss: 0.2449 (0.2560)  loss_classifier: 0.0874 (0.0921)  loss_box_reg: 0.1415 (0.1466)  loss_objectness: 0.0074 (0.0111)  loss_rpn_box_reg: 0.0044 (0.0061)  time: 1.7151
# Epoch: [5]  [400/500]  eta: 0:02:53  lr: 0.000500  loss: 0.2293 (0.2556)  loss_classifier: 0.0822 (0.0919)  loss_box_reg: 0.1304 (0.1465)  loss_objectness: 0.0078 (0.0112)  loss_rpn_box_reg: 0.0047 (0.0061)  time: 1.7051
# Epoch: [5]  [420/500]  eta: 0:02:18  lr: 0.000500  loss: 0.2481 (0.2557)  loss_classifier: 0.0905 (0.0918)  loss_box_reg: 0.1546 (0.1467)  loss_objectness: 0.0083 (0.0111)  loss_rpn_box_reg: 0.0051 (0.0061)  time: 1.6965
# Epoch: [5]  [440/500]  eta: 0:01:43  lr: 0.000500  loss: 0.2435 (0.2553)  loss_classifier: 0.0949 (0.0916)  loss_box_reg: 0.1409 (0.1466)  loss_objectness: 0.0075 (0.0110)  loss_rpn_box_reg: 0.0049 (0.0060)  time: 1.6909
# Epoch: [5]  [460/500]  eta: 0:01:09  lr: 0.000500  loss: 0.2471 (0.2555)  loss_classifier: 0.0841 (0.0915)  loss_box_reg: 0.1519 (0.1468)  loss_objectness: 0.0080 (0.0110)  loss_rpn_box_reg: 0.0049 (0.0061)  time: 1.8756
# Epoch: [5]  [480/500]  eta: 0:00:35  lr: 0.000500  loss: 0.2598 (0.2562)  loss_classifier: 0.0904 (0.0916)  loss_box_reg: 0.1518 (0.1474)  loss_objectness: 0.0060 (0.0109)  loss_rpn_box_reg: 0.0051 (0.0062)  time: 2.3268
# Epoch: [5]  [499/500]  eta: 0:00:01  lr: 0.000500  loss: 0.2147 (0.2552)  loss_classifier: 0.0784 (0.0912)  loss_box_reg: 0.1147 (0.1469)  loss_objectness: 0.0101 (0.0109)  loss_rpn_box_reg: 0.0047 (0.0062)  time: 1.7333
# Epoch: [5] Total time: 0:14:40 (1.7605 s / it)
# Epoch:  5 | val acc: 0.8060 | val auc: 0.9332
# Best Epoch:  5 | val acc: 0.8060 | Best val auc: 0.9332
# Epoch: [6]  [  0/500]  eta: 0:49:50  lr: 0.000500  loss: 0.1578 (0.1578)  loss_classifier: 0.0487 (0.0487)  loss_box_reg: 0.1007 (0.1007)  loss_objectness: 0.0035 (0.0035)  loss_rpn_box_reg: 0.0049 (0.0049)  time: 5.9802
# Epoch: [6]  [ 20/500]  eta: 0:15:32  lr: 0.000500  loss: 0.2429 (0.2365)  loss_classifier: 0.0823 (0.0812)  loss_box_reg: 0.1394 (0.1423)  loss_objectness: 0.0069 (0.0079)  loss_rpn_box_reg: 0.0050 (0.0051)  time: 1.7399
# Epoch: [6]  [ 40/500]  eta: 0:13:54  lr: 0.000500  loss: 0.2413 (0.2374)  loss_classifier: 0.0844 (0.0837)  loss_box_reg: 0.1287 (0.1412)  loss_objectness: 0.0058 (0.0077)  loss_rpn_box_reg: 0.0043 (0.0048)  time: 1.6788
# Epoch: [6]  [ 60/500]  eta: 0:13:04  lr: 0.000500  loss: 0.2324 (0.2415)  loss_classifier: 0.0902 (0.0854)  loss_box_reg: 0.1280 (0.1432)  loss_objectness: 0.0071 (0.0080)  loss_rpn_box_reg: 0.0052 (0.0049)  time: 1.7173
# Epoch: [6]  [ 80/500]  eta: 0:12:20  lr: 0.000500  loss: 0.2143 (0.2378)  loss_classifier: 0.0758 (0.0839)  loss_box_reg: 0.1275 (0.1401)  loss_objectness: 0.0074 (0.0085)  loss_rpn_box_reg: 0.0055 (0.0053)  time: 1.7025
# Epoch: [6]  [100/500]  eta: 0:11:39  lr: 0.000500  loss: 0.2245 (0.2384)  loss_classifier: 0.0809 (0.0833)  loss_box_reg: 0.1368 (0.1391)  loss_objectness: 0.0087 (0.0096)  loss_rpn_box_reg: 0.0047 (0.0064)  time: 1.6891
# Epoch: [6]  [120/500]  eta: 0:11:00  lr: 0.000500  loss: 0.2765 (0.2416)  loss_classifier: 0.0945 (0.0845)  loss_box_reg: 0.1628 (0.1413)  loss_objectness: 0.0090 (0.0096)  loss_rpn_box_reg: 0.0054 (0.0062)  time: 1.6913
# Epoch: [6]  [140/500]  eta: 0:10:23  lr: 0.000500  loss: 0.2388 (0.2418)  loss_classifier: 0.0821 (0.0844)  loss_box_reg: 0.1382 (0.1418)  loss_objectness: 0.0065 (0.0094)  loss_rpn_box_reg: 0.0050 (0.0062)  time: 1.6960
# Epoch: [6]  [160/500]  eta: 0:09:47  lr: 0.000500  loss: 0.2115 (0.2407)  loss_classifier: 0.0781 (0.0842)  loss_box_reg: 0.1281 (0.1410)  loss_objectness: 0.0084 (0.0094)  loss_rpn_box_reg: 0.0048 (0.0061)  time: 1.6998
# Epoch: [6]  [180/500]  eta: 0:09:12  lr: 0.000500  loss: 0.2023 (0.2387)  loss_classifier: 0.0721 (0.0833)  loss_box_reg: 0.1168 (0.1395)  loss_objectness: 0.0088 (0.0099)  loss_rpn_box_reg: 0.0049 (0.0060)  time: 1.7052
# Epoch: [6]  [200/500]  eta: 0:08:37  lr: 0.000500  loss: 0.2445 (0.2410)  loss_classifier: 0.0923 (0.0841)  loss_box_reg: 0.1382 (0.1407)  loss_objectness: 0.0094 (0.0099)  loss_rpn_box_reg: 0.0054 (0.0062)  time: 1.7181
# Epoch: [6]  [220/500]  eta: 0:08:02  lr: 0.000500  loss: 0.2375 (0.2410)  loss_classifier: 0.0741 (0.0843)  loss_box_reg: 0.1356 (0.1406)  loss_objectness: 0.0083 (0.0099)  loss_rpn_box_reg: 0.0051 (0.0062)  time: 1.6984
# Epoch: [6]  [240/500]  eta: 0:07:45  lr: 0.000500  loss: 0.2378 (0.2417)  loss_classifier: 0.0888 (0.0846)  loss_box_reg: 0.1350 (0.1413)  loss_objectness: 0.0066 (0.0097)  loss_rpn_box_reg: 0.0052 (0.0061)  time: 2.5518
# Epoch: [6]  [260/500]  eta: 0:07:29  lr: 0.000500  loss: 0.2254 (0.2410)  loss_classifier: 0.0817 (0.0844)  loss_box_reg: 0.1239 (0.1408)  loss_objectness: 0.0088 (0.0097)  loss_rpn_box_reg: 0.0048 (0.0062)  time: 2.8740
# Epoch: [6]  [280/500]  eta: 0:06:59  lr: 0.000500  loss: 0.2190 (0.2409)  loss_classifier: 0.0788 (0.0844)  loss_box_reg: 0.1300 (0.1407)  loss_objectness: 0.0060 (0.0096)  loss_rpn_box_reg: 0.0050 (0.0061)  time: 2.2999
# Epoch: [6]  [300/500]  eta: 0:06:21  lr: 0.000500  loss: 0.2372 (0.2417)  loss_classifier: 0.0859 (0.0847)  loss_box_reg: 0.1317 (0.1412)  loss_objectness: 0.0088 (0.0096)  loss_rpn_box_reg: 0.0059 (0.0061)  time: 1.9648
# Epoch: [6]  [320/500]  eta: 0:05:42  lr: 0.000500  loss: 0.2484 (0.2432)  loss_classifier: 0.0876 (0.0851)  loss_box_reg: 0.1435 (0.1421)  loss_objectness: 0.0084 (0.0098)  loss_rpn_box_reg: 0.0057 (0.0061)  time: 1.8353
# Epoch: [6]  [340/500]  eta: 0:05:18  lr: 0.000500  loss: 0.2370 (0.2433)  loss_classifier: 0.0838 (0.0852)  loss_box_reg: 0.1485 (0.1423)  loss_objectness: 0.0084 (0.0098)  loss_rpn_box_reg: 0.0047 (0.0061)  time: 3.3493
# Epoch: [6]  [360/500]  eta: 0:04:36  lr: 0.000500  loss: 0.2068 (0.2417)  loss_classifier: 0.0754 (0.0847)  loss_box_reg: 0.1211 (0.1412)  loss_objectness: 0.0075 (0.0097)  loss_rpn_box_reg: 0.0039 (0.0060)  time: 1.7169
# Epoch: [6]  [380/500]  eta: 0:03:55  lr: 0.000500  loss: 0.2264 (0.2410)  loss_classifier: 0.0777 (0.0845)  loss_box_reg: 0.1400 (0.1410)  loss_objectness: 0.0071 (0.0096)  loss_rpn_box_reg: 0.0043 (0.0059)  time: 1.6960
# Epoch: [6]  [400/500]  eta: 0:03:14  lr: 0.000500  loss: 0.2380 (0.2404)  loss_classifier: 0.0750 (0.0842)  loss_box_reg: 0.1303 (0.1407)  loss_objectness: 0.0071 (0.0095)  loss_rpn_box_reg: 0.0047 (0.0059)  time: 1.7234
# Epoch: [6]  [420/500]  eta: 0:02:38  lr: 0.000500  loss: 0.2411 (0.2407)  loss_classifier: 0.0786 (0.0843)  loss_box_reg: 0.1443 (0.1409)  loss_objectness: 0.0069 (0.0095)  loss_rpn_box_reg: 0.0047 (0.0059)  time: 2.6826
# Epoch: [6]  [440/500]  eta: 0:01:58  lr: 0.000500  loss: 0.2353 (0.2406)  loss_classifier: 0.0813 (0.0844)  loss_box_reg: 0.1395 (0.1407)  loss_objectness: 0.0085 (0.0097)  loss_rpn_box_reg: 0.0055 (0.0059)  time: 1.7857
# Epoch: [6]  [460/500]  eta: 0:01:19  lr: 0.000500  loss: 0.2146 (0.2402)  loss_classifier: 0.0750 (0.0842)  loss_box_reg: 0.1289 (0.1405)  loss_objectness: 0.0069 (0.0095)  loss_rpn_box_reg: 0.0043 (0.0059)  time: 2.1631
# Epoch: [6]  [480/500]  eta: 0:00:39  lr: 0.000500  loss: 0.2412 (0.2403)  loss_classifier: 0.0768 (0.0842)  loss_box_reg: 0.1377 (0.1407)  loss_objectness: 0.0062 (0.0095)  loss_rpn_box_reg: 0.0048 (0.0059)  time: 1.6909
# Epoch: [6]  [499/500]  eta: 0:00:01  lr: 0.000500  loss: 0.2410 (0.2400)  loss_classifier: 0.0752 (0.0840)  loss_box_reg: 0.1373 (0.1406)  loss_objectness: 0.0068 (0.0094)  loss_rpn_box_reg: 0.0050 (0.0060)  time: 1.6727
# Epoch: [6] Total time: 0:16:19 (1.9587 s / it)
# Epoch:  6 | val acc: 0.7930 | val auc: 0.9288

# %% [markdown]
# This part is used for applying and testing the model

# %%
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
model = _get_detection_model(2)
model.to(device)

# get the trained model 
model.load_state_dict(torch.load("drive/MyDrive/object-cxr/model.pt"))
# put the model in evaluation mode
model.eval()
data_transforms = transforms.Compose([
    transforms.Resize((600,600)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])
# define the dataset use for test
dataset_dev = ForeignObjectDataset(datafolder= data_dir + 'dev/', datatype='dev',
                                       transform=data_transforms,
                                       labels_dict=img_class_dict_dev)
# define the test data loaders
data_loader_val = torch.utils.data.DataLoader(
    dataset_dev, batch_size=1, shuffle= False, num_workers=4,
    collate_fn=utils.collate_fn)

preds = []
labels = []
locs = []

# iterable-style dataset
from tqdm import tqdm
for image, label, width, height in data_loader_val:
    
    image = list(img.to(device) for img in image)
    labels.append(label[-1])
    
    outputs = model(image)
    
    center_points = []
    center_points_preds = []
    bbox = []
    
    if len(outputs[-1]['boxes']) == 0:
        preds.append(0)
        center_points.append([])
        center_points_preds.append('')
        bbox.append('')
        locs.append('')
    else:
        preds.append(torch.max(outputs[-1]['scores']).tolist())
        
        new_output_index = torch.where((outputs[-1]['scores']>0.1))
        new_boxes = outputs[-1]['boxes'][new_output_index]
        new_scores = outputs[-1]['scores'][new_output_index]
        line = ''
        for i in range(len(new_boxes)):
            new_box = new_boxes[i].tolist()
            center_x = (new_box[0] + new_box[2])/2
            center_y = (new_box[1] + new_box[3])/2
            center_points.append([center_x/600 * width[-1],center_y/600 * height[-1]])
            bbox.append([new_box[0]/600 * width[-1], new_box[2]/600 * width[-1], new_box[1]/600 * height[-1] ,new_box[3]/600 * height[-1] ])
            if i == len(new_boxes)-1:
                line += str(center_points[i][0]) + ' ' + str(center_points[i][1]) + ' ' + str(bbox[i][0]) + ' ' + str(bbox[i][1]) + ' '+ str(bbox[i][2]) + ' ' + str(bbox[i][3])
            else:
                line += str(center_points[i][0]) + ' ' + str(center_points[i][1]) + ' ' + str(bbox[i][0]) + ' ' + str(bbox[i][1]) + ' ' + str(bbox[i][2]) + ' ' + str(bbox[i][3]) +';'
        locs.append(line)
        center_points_preds += new_scores.tolist()

# save the result to the excel file

# score for prediction 
cls_res = pd.DataFrame({'image_name': dataset_dev.image_files_list, 'prediction': preds})
cls_res.to_csv('classification.csv', columns=['image_name', 'prediction'], sep=',', index=None)
print('classification.csv generated.')

# position of the detected object
loc_res = pd.DataFrame({'image_name': dataset_dev.image_files_list, 'prediction': locs})
loc_res.to_csv('localization.csv', columns=['image_name', 'prediction'], sep=',', index=None)
print('localization.csv generated.')
# Out:
# classification.csv generated.
# localization.csv generated.

# %% [markdown]
# Visualizing the result from the test above

# %%
def draw_res(im,str,fill = (0, 0, 0, 40)):
  draw = ImageDraw.Draw(im, mode="RGBA")
  for centers in str.split(OBJECT_SEP):
    centers = list(map(float, centers.split(ANNOTATION_SEP)))
    print(centers[2:])
    cx,cy = centers[:2]
    x0,x1,y0,y1 = centers[2:]
    draw.ellipse((cx-20,cy-20,cx+20,cy+20), fill = '#ff0000')
    draw.rectangle((x0,y0,x1,y1), outline='green', width=10)

fig, axs = plt.subplots(
    nrows=1, ncols=4, subplot_kw=dict(xticks=[], yticks=[]), figsize=(24, 6)
)
label = pd.read_csv('localization.csv', na_filter=False)
example_idxes = [9,35,37,234]
for row, ax in zip(
    label.iloc[example_idxes].itertuples(index=False), axs
):
    im = Image.open(data_dir + "dev/" + row.image_name).convert("RGB")
    if row.prediction:
        draw_res(im,row.prediction)
    
    ax.imshow(im)
    ax.set_title(f"{row.image_name}")
# Out:
# [1139.8548199462891, 1657.216226501465, 821.7467656962077, 1329.3755881245932]
# [1014.3455058288574, 1165.9735707092286, 481.1437096913656, 650.8167123158772]
# [1701.562841796875, 1868.5181921386718, 584.6814677174887, 759.9087299092611]
# [767.2681877136231, 1156.0062817382814, 207.99702322642008, 662.0732538604736]
# [1180.6219760131837, 1317.614105834961, 855.7663473256429, 985.2691451263428]
# [972.9031750488282, 1814.4459255981444, 445.9043678410848, 1334.0734119669596]
# [1517.2068673706056, 1653.697907104492, 902.6835389709472, 1031.2410021209716]
# [1310.3068270874023, 1477.829537963867, 1142.6339917500813, 1299.1314327494304]
# [1757.6398962402343, 2136.6649517822266, 138.55421146392823, 628.5133395131429]
# [766.5439871215821, 1037.0535375976563, 187.09546467463176, 527.3616058603923]
# [924.7916857910155, 1170.3375865173339, 437.35194213867186, 659.8302655792236]
# [1691.0923962402344, 2021.3352770996094, 208.19031428019207, 746.5473210906982]
# [1820.4564413452147, 2069.415270080566, 154.88887263615925, 504.253370107015]
# [1003.7685287475587, 1334.6628552246093, 486.69447883605955, 1014.3929460906983]
# [1426.041107788086, 1864.1970739746093, 567.1966588846842, 1033.8836081695556]
# [931.5958374023437, 1594.9653442382812, 1646.6998777262368, 2324.203616434733]
# [2058.2077026367188, 2272.44453125, 656.9372032165528, 924.959426574707]
# [1442.8878784179688, 1721.696875, 39.88813649654388, 310.5393942642212]
# [0.0, 217.98820953369142, 651.1309590657552, 798.2092386372884]
# [3.2489928245544433, 168.9441261291504, 1203.1224679056804, 1426.1166549173993]
